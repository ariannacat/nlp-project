# %%
'''from google.colab import drive
drive.mount('/content/drive')'''
# Out:
# Mounted at /content/drive

# %%
# Define evaluation queries

queries = [
    "Is limits of human knowledge compatible with human intuition?",
    "How does the role of imagination shape our understanding of the universe?",
    "Can line spectra be explained without contradictions?",
    "Can entanglement be explained without contradictions?",
    "Could we have discovered spectral lines without experiments?",
    "Why is geometry and experience considered revolutionary?",
    "Could we have discovered quantum theory without experiments?",
    "How does constitution of radiation relate to our everyday experience?",
    "What does limits of human knowledge tell us about reality?",
    "What makes scientific method a cornerstone of modern science?",
    "What does international cooperation in science tell us about reality?",
    "What does gravity tell us about reality?",
    "Could we have discovered international cooperation in science without experiments?",
    "Does quantum jumps challenge classical physics?",
    "How does philosophy of quantum physics shape our understanding of the universe?",
    "Can international cooperation in science be explained without contradictions?",
    "What are the philosophical implications of philosophy of science?",
    "Is interference compatible with human intuition?",
    "How does philosophy of science relate to our everyday experience?",
    "Could we have discovered relativity without experiments?",
    "How does inertia shape our understanding of the universe?",
    "What does line spectra tell us about reality?",
    "Does scientific method challenge classical physics?",
    "How does role of the observer shape our understanding of the universe?",
    "Can complementarity be explained without contradictions?",
    "Is pacifism compatible with human intuition?",
    "Could we have discovered interference without experiments?",
    "How does entanglement relate to our everyday experience?",
    "Can the role of imagination be explained without contradictions?",
    "What makes relativity a cornerstone of modern science?",
    "Can philosophy of quantum physics be explained without contradictions?",
    "Could we have discovered complementarity without experiments?",
    "Is Brownian motion compatible with human intuition?",
    "Could we have discovered wave-particle duality without experiments?",
    "What are the philosophical implications of atomic structure?",
    "Could we have discovered line spectra without experiments?",
    "What are the philosophical implications of complementarity?",
    "Could we have discovered causality without experiments?",
    "Why is measurement problem considered revolutionary?",
    "Is space and time compatible with human intuition?",
    "Can quantum jumps be explained without contradictions?",
    "How does line spectra shape our understanding of the universe?",
    "Why is line spectra considered revolutionary?",
    "Why is atomic structure considered revolutionary?",
    "Could we have discovered pacifism without experiments?",
    "Can probabilistic reality be explained without contradictions?",
    "Is inertia compatible with human intuition?",
    "What does space and time tell us about reality?",
    "Why is causality considered revolutionary?",
    "Is geometry and experience compatible with human intuition?",
    "What makes causality in physics a cornerstone of modern science?",
    "What makes gravity a cornerstone of modern science?",
    "Why is spectral lines considered revolutionary?",
    "How does observation in physics relate to our everyday experience?",
    "How does nature of light relate to our everyday experience?",
    "How does atomic structure relate to our everyday experience?",
    "How does wave-particle duality shape our understanding of the universe?",
    "How does social responsibility of science relate to our everyday experience?",
    "Why is international cooperation in science considered revolutionary?",
    "Does gravity challenge classical physics?"
]

# %%
import numpy as np
import pandas as pd
import time
from sentence_transformers import SentenceTransformer
from sklearn.neighbors import NearestNeighbors

# Load cleaned Bohr corpus and compute mean style embedding
CLEANED_PATH_BOHR = 'bohr_cleaned_final.txt'
with open(CLEANED_PATH_BOHR, 'r', encoding='utf-8') as f:
    lines_bohr = [l.strip() for l in f if l.strip()]

# Load cleaned Einstein corpus and compute mean style embedding
CLEANED_PATH_EINSTEIN = 'einstein_cleaned_final.txt'
with open(CLEANED_PATH_EINSTEIN, 'r', encoding='utf-8') as f:
    lines_einstein = [l.strip() for l in f if l.strip()]


# Initialize embedder and compute mean embedding of a random sample of passages
embedder = SentenceTransformer("all-MiniLM-L6-v2")

sample_bohr = np.random.choice(lines_bohr, min(len(lines_bohr), 200), replace=False)
sample_einstein = np.random.choice(lines_einstein, min(len(lines_einstein), 200), replace=False)

mean_emb_bhor = embedder.encode(sample_bohr.tolist(), convert_to_numpy=True).mean(axis=0)
mean_emb_einstein = embedder.encode(sample_einstein.tolist(), convert_to_numpy=True).mean(axis=0)

mean_emb = (mean_emb_bhor + mean_emb_einstein) / 2
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Auxiliary function to compute internal repetition score
def repetition_score(text):
    sentences = [s.strip() for s in text.split('.') if len(s.strip().split()) > 3]
    if len(sentences) < 2:
        return 0.0
    tfidf = TfidfVectorizer().fit_transform(sentences)
    sim_matrix = cosine_similarity(tfidf)
    n = len(sentences)
    repetition = (sim_matrix.sum() - n) / (n * (n - 1))
    return repetition

# Main evaluation function
def evaluate_model_metrics(model_fn, model_name="CustomModel", verbose=False):
    """
    Evaluate textual quality and semantic relevance of a generative model.

    Args:
        model_fn (function): A function that takes a query string and returns a generated response.
        model_name (str): Optional name for the model (used in output).
        verbose (bool): If True, prints each query and generated response.

    Returns:
        dict: Dictionary of average evaluation metrics.
    """
    records = []

    for query in queries[:10]:
        start = time.time()
        response = model_fn(query)
        if response is None:
            print(f"[ERROR] No valid response for query: {query}")
            continue

        gen_time = time.time() - start

        if verbose:
            print(f"\n[Query] {query}\n[Response] {response}\n")

        tokens = response.split()
        length = len(tokens)
        lex_div = len(set(tokens)) / length if length else 0
        bigrams = list(zip(tokens, tokens[1:]))
        distinct1 = len(set(tokens)) / length if length else 0
        distinct2 = len(set(bigrams)) / len(bigrams) if bigrams else 0
        sentences = [s.strip() for s in response.split('.') if s.strip()]
        sent_lens = [len(s.split()) for s in sentences]
        avg_sent_len = np.mean(sent_lens) if sent_lens else 0

        # Style similarity to Einstein corpus
        resp_emb = embedder.encode([response], convert_to_numpy=True)[0]
        style_sim = float(np.dot(resp_emb, mean_emb) / (np.linalg.norm(resp_emb) * np.linalg.norm(mean_emb)))

        # Semantic relevance (query-to-response similarity)
        query_emb = embedder.encode([query], convert_to_numpy=True)[0]
        query_sim = float(np.dot(query_emb, resp_emb) / (np.linalg.norm(query_emb) * np.linalg.norm(resp_emb)))

        # Internal repetition
        repetition = repetition_score(response)

        records.append({
            "Query": query,
            "Tokens": length,
            "LexDiv": lex_div,
            "Distinct-1": distinct1,
            "Distinct-2": distinct2,
            "AvgSentLen": avg_sent_len,
            "StyleSim": style_sim,
            "QuerySim": query_sim,
            "Repetition": repetition,
            "GenTime(s)": round(gen_time, 3)
        })

    df = pd.DataFrame(records)
    metric_cols = ["Tokens", "LexDiv", "Distinct-1", "Distinct-2", "AvgSentLen",
                   "StyleSim", "QuerySim", "Repetition", "GenTime(s)"]
    summary = df[metric_cols].mean().to_dict()

    print(f"\n=== Metrics for {model_name} ===")
    for metric, value in summary.items():
        print(f"{metric}: {value:.4f}")

    return summary

# %% [markdown]
# The baseline is a generator which is trained just on its own parameters and not referring to files that, in other models, we retrieve, so the baseline answers out of its own pretraining.

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 70.1 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0

# %% [markdown]
# ### BASELINE CHATBOT

# %%
import pandas as pd
import numpy as np
import time
import random
from IPython.display import display
from sentence_transformers import SentenceTransformer
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
import faiss

# Load FAISS index
print("[EVAL] Building FAISS index...")
passage_embeddings_einstein = embedder.encode(lines_einstein, convert_to_numpy=True, show_progress_bar=True)
passage_embeddings_bohr = embedder.encode(lines_bohr, convert_to_numpy=True, show_progress_bar=True)
passage_embeddings = np.vstack([passage_embeddings_einstein, passage_embeddings_bohr])

index = faiss.IndexFlatL2(passage_embeddings.shape[1])
index.add(passage_embeddings)
print("[EVAL] FAISS index ready.")

baseline_tokenizer = AutoTokenizer.from_pretrained("gpt2")
baseline_model     = AutoModelForCausalLM.from_pretrained("gpt2")
baseline_pipe      = pipeline(
    "text-generation",
    model=baseline_model,
    tokenizer=baseline_tokenizer,
    device=-1
)

def baseline_chatbot(prompt: str, max_new_tokens: int = 50):
    full = f"You are a helpful assistant. Answer succinctly:\n\nQuestion: {prompt}\nAnswer:"
    out = baseline_pipe(
        full,
        max_new_tokens=max_new_tokens,
        do_sample=True,
        top_p=0.9,
        temperature=0.8,
        pad_token_id=baseline_tokenizer.eos_token_id
    )[0]["generated_text"]
    return out.split("Answer:")[-1].strip()


evaluate_model_metrics(baseline_chatbot, model_name="BASELINE", verbose=True)
# Out:
# [EVAL] Building FAISS index...
# Batches:   0%|          | 0/101 [00:00<?, ?it/s]
# Batches:   0%|          | 0/77 [00:00<?, ?it/s]
# [EVAL] FAISS index ready.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Device set to use cpu
# [Query] Is limits of human knowledge compatible with human intuition?
# [Response] The human intuition of intuition is not based on any kind of naturalistic logic, but rather is based on an assumption that all knowledge is rational and that it can be obtained by means of a finite number of rational guesses. For example, suppose that we
#
#
# [Query] How does the role of imagination shape our understanding of the universe?
# [Response] If you are a scientist, you are the only one who can make the scientific claims. If you are a mathematician, you are the only one who can determine what the universe is really like. If you are a biologist, you are the only one
#
#
# [Query] Can line spectra be explained without contradictions?
# [Response] Question: Can the line spectra be explained without contradictions?
#
#
# [Query] Can entanglement be explained without contradictions?
# [Response] No
#
#
# [Query] Could we have discovered spectral lines without experiments?
# [Response] Yes, we could have. The spectral lines we found could be derived from some of the spectral lines in our data, and therefore they are not indicative of our experiments. If they were, we could be sure that we could have found them. So
#
#
# [Query] Why is geometry and experience considered revolutionary?
# [Response] I am a psychologist. I work with students from all over the world. I know the concepts of physics and chemistry, chemistry and psychology. I know what physics and chemistry are. I know what mathematics and physics are. And I have a lot of
#
#
# [Query] Could we have discovered quantum theory without experiments?
# [Response] We are not able to study the properties of molecules. For example, we cannot observe the behavior of the molecules
#
#
# [Query] How does constitution of radiation relate to our everyday experience?
# [Response] The human body is made up of a large number of cells which are all interconnected and interacting, each of which has a unique function. The body is an organism whose actions have no limits and which is constantly changing, expanding, and growing.
#
#
# [Query] What does limits of human knowledge tell us about reality?
# [Response] This is a good question, because if we have a hard-wired sense of the world, we know that we live in a world where everything we see is real, and that we must be willing to give up all of that information to find out
#
#
# [Query] What makes scientific method a cornerstone of modern science?
# [Response] Scientific method is an understanding of the natural world. It is the primary means of understanding the workings of the universe. Scientific method is the art of understanding the workings of the natural world.
#
# Question: What is the most important element of scientific method
#
#
# === Metrics for BASELINE ===
# Tokens: 34.1000
# LexDiv: 0.7350
# Distinct-1: 0.7350
# Distinct-2: 0.8080
# AvgSentLen: 15.3833
# StyleSim: 0.2559
# QuerySim: 0.5025
# Repetition: 0.1903
# GenTime(s): 5.4333
# {'Tokens': 34.1,
#  'LexDiv': 0.7350005106678514,
#  'Distinct-1': 0.7350005106678514,
#  'Distinct-2': 0.8079761065807578,
#  'AvgSentLen': 15.383333333333331,
#  'StyleSim': 0.2559481764212251,
#  'QuerySim': 0.502513162046671,
#  'Repetition': 0.190343803317461,
#  'GenTime(s)': 5.433300000000001}

# %% [markdown]
# # MODEL 5: GPT-Neo 1.3B with Dynamic Context Truncation
#
# In this fifth model, we introduce a refined version of the GPT-Neo-based RAG pipeline. Instead of simply scaling the generator up, this version prioritizes *efficient use of the input token window* by dynamically adapting how much context to include for each query. We also adopt a more detailed, structured prompt to guide answer style and length.
#
# 1) **Corpus and Embedding (unchanged)**
# We reuse the same cleaned Einstein corpus and embed each paragraph using the `all-MiniLM-L6-v2` SentenceTransformer model. All embeddings are indexed using FAISS for fast nearest-neighbor search via L2 distance.
#
# 2) **Generator Upgrade: GPT-Neo 1.3B**
# We switch from GPT-Neo 2.7B to the lighter `gpt-neo-1.3B` model. While smaller, this version still provides high-quality outputs and is more manageable in environments with limited GPU memory (e.g., Colab).
#
# 3) **Smart Context Assembly**
# Instead of blindly retrieving `k=7` passages and concatenating all of them, we build the input **dynamically**, one paragraph at a time. After each addition, we test whether the resulting prompt (including the final question and instructions) still fits within the model’s token limit. This ensures we use *as much relevant context as possible* without truncation, which is especially important for long-generation models.
#
# 4) **Prompting Strategy**
# The prompt tells the model to act as Albert Einstein and provide a clear, thoughtful, and concise answer based on the retrieved "excerpts." It explicitly instructs the model *not to mention the excerpts*, which helps avoid meta comments. The target answer length is 3–5 sentences.
#
# 5) **Generation Details**
# We sample up to 400 new tokens using `top_p` sampling with moderate temperature, and apply a `no_repeat_ngram_size` of 3 to prevent redundant phrasing.
#
# 6) **Post-processing**
# We extract the answer from the generated output after the “Answer:” token, clean it up, and trim trailing content after known markers (like “---” or repeated prompt sections). We also ensure the answer ends with a full stop and makes grammatical sense.
#
# **Key Differences from Model 4:**
# - **Smaller model (1.3B vs 2.7B)**, better for memory-constrained environments.
# - **Dynamic context selection** ensures optimal use of token budget with no waste or hard truncation.
# - **Stronger prompt structure** guides both tone and content.
# - **Improved repetition control** using `no_repeat_ngram_size`.
#
# This model finds a sweet spot between resource efficiency and generation quality. Thanks to smarter context management and focused prompting, it often produces answers that are just as good—if not better—than its larger predecessor.

# %%
import gc
import torch
gc.collect()
torch.cuda.empty_cache()

# %%
import os
import time
import numpy as np
from sentence_transformers import SentenceTransformer
import faiss
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Step 1: Load the cleaned corpus
print("[1/8] Loading corpus...")
corpus_path = 'einstein_cleaned_final.txt'
with open(corpus_path, 'r', encoding='utf-8') as f:
    passages = [line.strip() for line in f if line.strip()]
print(f"[1/8] Corpus loaded: {len(passages)} passages\n")

# Step 2: Initialize the SentenceTransformer embedder
print("[2/8] Initializing SentenceTransformer...")
embedder = SentenceTransformer('all-MiniLM-L6-v2')
print("[2/8] Embedder ready\n")

# Step 3: Compute passage embeddings and build FAISS index
print("[3/8] Computing embeddings and indexing...")
batch_size = 64
emb_chunks = []
start = time.time()
for i in range(0, len(passages), batch_size):
    batch = passages[i:i+batch_size]
    embs = embedder.encode(batch, convert_to_numpy=True, show_progress_bar=False)
    emb_chunks.append(embs)
    print(f"    [3/8] Batch {i//batch_size+1}/{(len(passages)-1)//batch_size+1} completed")
passage_embeddings = np.vstack(emb_chunks)
dim = passage_embeddings.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(passage_embeddings)
print(f"[3/8] Indexed {passage_embeddings.shape[0]} vectors in {time.time()-start:.1f}s\n")

# Step 4: Load the GPT-Neo 1.3B model and tokenizer
print("[4/8] Initializing tokenizer and GPT-Neo (1.3B)...")
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neo-1.3B")
generator_model = AutoModelForCausalLM.from_pretrained("EleutherAI/gpt-neo-1.3B")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generator_model.to(device)
print(f"[4/8] Model and tokenizer ready (device={device})\n")

# Step 5–7: Define the RAG pipeline using GPT-Neo 1.3B
def einstein_chatbot(query, k=7, max_new_tokens=400, top_p=0.8, temperature=0.7):
    print(f"\n[5/8] Processing query: {query!r}")

    q_emb = embedder.encode([query], convert_to_numpy=True)
    D, I = index.search(q_emb, k)

    total_tokens = 0
    context_chunks = []

    # Dynamically accumulate context passages until input length limit
    for idx in I[0]:
        para_text = passages[idx][:1500]
        test_prompt = (
            f"You are Albert Einstein. Based on the following excerpts, answer the question in your own words. "
            "Provide a clear, thoughtful, and concise answer in 3–5 complete sentences. "
            "Do not refer to the excerpts or sources. Just answer directly.\n\n"
            "Excerpts:\n" + "\n---\n".join(context_chunks + [para_text]) + f"\n\nQuestion: {query}\nAnswer:"
        )
        token_count = len(tokenizer.encode(test_prompt))

        if token_count < tokenizer.model_max_length - max_new_tokens:
            context_chunks.append(para_text)
            total_tokens = token_count
        else:
            break

    print(f"[5/8] Collected {len(context_chunks)} context passages (approx. {total_tokens} tokens)\n")

    context_text = "\n---\n".join(context_chunks)
    prompt = (
        f"You are Albert Einstein. Based on the following excerpts, answer the question in your own words. "
        "Provide a clear, thoughtful, and concise answer in 3–5 complete sentences. "
        "Do not refer to the excerpts or sources. Just answer directly.\n\n"
        "Excerpts:\n" + context_text + f"\n\nQuestion: {query}\nAnswer:"
    )

    max_input_tokens = tokenizer.model_max_length
    input_ids = tokenizer.encode(prompt, return_tensors="pt", truncation=True, max_length=max_input_tokens).to(device)
    print(f"[6/8] Prompt ready (tokens={input_ids.shape[1]}/{max_input_tokens})")

    output_ids = generator_model.generate(
        input_ids,
        max_new_tokens=max_new_tokens,
        do_sample=True,
        top_p=top_p,
        temperature=temperature,
        pad_token_id=tokenizer.eos_token_id,
        no_repeat_ngram_size=3
    )

    generated_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Extract only the answer portion
    if "Answer:" in generated_text:
        answer = generated_text.split("Answer:")[-1].strip()
    else:
        answer = generated_text.strip()

    for stop_token in ["---", "\n\n", "\nAnswer:"]:
        if stop_token in answer:
            answer = answer.split(stop_token)[0].strip()
    if '.' in answer:
        answer = '.'.join(answer.split('.')[:-1]) + '.'

    print("[7/8] Answer generated")
    return answer

# Step 8: Run example queries
example_queries = [
    "What is the nature of time?",
    "How would you describe imagination?",
    "What is the nature of light?"
]

for q in example_queries:
    print(f"\n=============================\nQuery: {q}")
    answer = einstein_chatbot(q)
    print(f"\nAnswer:\n{answer}")
    print("=============================")
# Out:
# [1/8] Loading corpus...
# [1/8] Corpus loaded: 3216 passages
#
# [2/8] Initializing SentenceTransformer...
# [2/8] Embedder ready
#
# [3/8] Computing embeddings and indexing...
#     [3/8] Batch 1/51 completed
#     [3/8] Batch 2/51 completed
#     [3/8] Batch 3/51 completed
#     [3/8] Batch 4/51 completed
#     [3/8] Batch 5/51 completed
#     [3/8] Batch 6/51 completed
#     [3/8] Batch 7/51 completed
#     [3/8] Batch 8/51 completed
#     [3/8] Batch 9/51 completed
#     [3/8] Batch 10/51 completed
#     [3/8] Batch 11/51 completed
#     [3/8] Batch 12/51 completed
#     [3/8] Batch 13/51 completed
#     [3/8] Batch 14/51 completed
#     [3/8] Batch 15/51 completed
#     [3/8] Batch 16/51 completed
#     [3/8] Batch 17/51 completed
#     [3/8] Batch 18/51 completed
#     [3/8] Batch 19/51 completed
#     [3/8] Batch 20/51 completed
#     [3/8] Batch 21/51 completed
#     [3/8] Batch 22/51 completed
#     [3/8] Batch 23/51 completed
#     [3/8] Batch 24/51 completed
#     [3/8] Batch 25/51 completed
#     [3/8] Batch 26/51 completed
#     [3/8] Batch 27/51 completed
#     [3/8] Batch 28/51 completed
#     [3/8] Batch 29/51 completed
#     [3/8] Batch 30/51 completed
#     [3/8] Batch 31/51 completed
#     [3/8] Batch 32/51 completed
#     [3/8] Batch 33/51 completed
#     [3/8] Batch 34/51 completed
#     [3/8] Batch 35/51 completed
#     [3/8] Batch 36/51 completed
#     [3/8] Batch 37/51 completed
#     [3/8] Batch 38/51 completed
#     [3/8] Batch 39/51 completed
#     [3/8] Batch 40/51 completed
#     [3/8] Batch 41/51 completed
#     [3/8] Batch 42/51 completed
#     [3/8] Batch 43/51 completed
#     [3/8] Batch 44/51 completed
#     [3/8] Batch 45/51 completed
#     [3/8] Batch 46/51 completed
#     [3/8] Batch 47/51 completed
#     [3/8] Batch 48/51 completed
#     [3/8] Batch 49/51 completed
#     [3/8] Batch 50/51 completed
#     [3/8] Batch 51/51 completed
# [3/8] Indexed 3216 vectors in 7.3s
#
# [4/8] Initializing tokenizer and GPT-Neo (1.3B)...
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.31G [00:00<?, ?B/s]
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# [4/8] Model and tokenizer ready (device=cuda)
#
#
# =============================
# Query: What is the nature of time?
#
# [5/8] Processing query: 'What is the nature of time?'
# [5/8] Collected 7 context passages (approx. 1096 tokens)
#
# [6/8] Prompt ready (tokens=1096/2048)
# [7/8] Answer generated
#
# Answer:
# Time is a quantity which can be directly measured. It does not exist apart from any observer.
# Question : What is a coordinate system?
# Ans. : A coordinate system is a set of co -ordinates. It has a well defined relation between them. It can be defined independently of the observer. It may be defined with reference to any observer, but not with reference only to the observer who defined it. It must be defined in terms of the coordinate system.
# Answer : A system of coordinates is a system of vectors. It defines a relation between vectors.
# Ex. : The vector A is a reference vector for a system which is not a coordinate-system.
# An example of a coordinate is the system which the observer uses to measure distances.
# A coordinate system has a relation to a reference system. The relation is a relation of vectors, and can be established with reference either to a coordinate or to a system. It need not be defined by reference to a particular system. A coordinate- system can be used in the same way as a reference- system, but it is a different system. If it is used for measuring distances, it must be used with reference, not to a certain system, or it will be useless.
# If we are dealing with a coordinate, we must first of course define it in terms.
# For example, if we have a system in which the vectors are defined by the positions of points, and the relations between them are given by a straight line, we can say that the system is in a coordinate.
# The relations of a system can also have the same meaning as the relations of the points in a point-system, but they must be given in terms, and must be established by reference.
# It may be necessary to define the system in terms in order that it may be used to measure.
# In a point system, the relation is given by the straight line.
# =============================
#
# =============================
# Query: How would you describe imagination?
#
# [5/8] Processing query: 'How would you describe imagination?'
# [5/8] Collected 7 context passages (approx. 1124 tokens)
#
# [6/8] Prompt ready (tokens=1124/2048)
# [7/8] Answer generated
#
# Answer:
# Imagination, as the name indicates, is the act of creating new ideas, of inventing new things. Imaginary ideas are the products not of thinking, but of a kind of thought-experience which is not based on the use of any concepts, but on the imagination of a certain kind of experience.
# Question 2: How is imagination related to the concept "idea"?
# Answer 2: Imaginary things are not real, but are only the products and products of the imagination.
# Answer 3: Imaginations are not based upon the use or the use-process of any concept, but upon the imagination or the imagination-process.
# Explanation:
# The imagination is a process which is based on an act of creation. The imagination is the result not of the use, but the use. The use is the creation of the product, i e. the product is not the product of the thinking, it is the product-of the imagination, which is the process of creation, and which is a product of thought. The product is the idea, which can be the product only of the process, and is not a product, but a product-process, which results from the process. The process is the imagination itself, which creates the product.
# A concept is not an idea, but is the "product" of the creation. A concept is a certain relation between the idea and the object.
# For example, the concept
# " A is a chair" is the relation of the idea "A is a" and the chair "is a chair."
# The product of this relation is the chair, and not the idea. The idea is not created, but created.
# In the same manner the concept,
# "A is an apple" is not "an apple," but the relation between "A" and "is an apple," and the apple "is" an apple.
# =============================
#
# =============================
# Query: What is the nature of light?
#
# [5/8] Processing query: 'What is the nature of light?'
# [5/8] Collected 7 context passages (approx. 1077 tokens)
#
# [6/8] Prompt ready (tokens=1077/2048)
# [7/8] Answer generated
#
# Answer:
# Light is a wave of energy. Light consists of a number of waves, which are produced by the vibration of the electromagnetic field. The waves are produced in the field of the electric or magnetic field.
# =============================

# %%
evaluate_model_metrics(einstein_chatbot, model_name="GPT-NEO 2", verbose=True)
# Out:
# [5/8] Processing query: 'Is limits of human knowledge compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 1020 tokens)
#
# [6/8] Prompt ready (tokens=1020/2048)
# [7/8] Answer generated
#
# [Query] Is limits of human knowledge compatible with human intuition?
# [Response] The limits of our human intuition are not compatible with the limits of the highest possible human intuition.
# Question : How can we know that the limits are not incompatible with the highest?
#  Answer : We can only know that they are not so incompatible.
# Answer : The limits are incompatible with human intuitions.
# The limits of intuition are incompatible only with the limit of human intuition, and not with the other limits.
# Questions: What is the limit to our intuition? What is a limit to the highest intuition? How can human intuition be incompatible with these limits?
# A limit to human intuition is not incompatible wiht the limits to human intuits. The limits to the human intui tion are not incompatibiliy with the human intuition itself. The limit to intuition is incompatible with our human intuitio.
# A limits to our intuitions is not incompatiy with our intuiti. The intuitions themselves are not limits to intuitions, and the intuitions are not limit to intuiti, but the limits, i.e. the intuiti are limits to intuition. The limitations to intuits are not in contradiction with intuiti and are not, therefore.
# How can human intuiti be incompatible?
# How do we know? How do we experience? How does intuition become knowledge?
# In order to know, we must experience. The intuition is the experience of the limit. The experience of intuition is that of the limits. The experi ence of the intuiting is that which is the result or the result ot the limits: the limits themselves.
# If the limits were incompatible with intuition, then intuition itself would not be the experience.
# An intuition is a feeling, a sensation, a perception, a feeling of a feeling. If the limits be incompatible wiH the intuitii, then the intuits themselves would not experience. They would not feel.
#
#
# [5/8] Processing query: 'How does the role of imagination shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 1222 tokens)
#
# [6/8] Prompt ready (tokens=1222/2048)
# [7/8] Answer generated
#
# [Query] How does the role of imagination shape our understanding of the universe?
# [Response] The imagination is the source of all our knowledge. It is the most powerful of all the faculties. It enables us to see and understand things that we otherwise would not be able to see or understand. It gives us the means to conceive the world in all its aspects, to make a new world and a new reality. It makes us feel that we are not alone in the universe. It helps us to realize that the universe is not a world but a "field" of things. It leads us to think of the world as a "game" in which we can play. It brings us to recognize that we do not exist in a vacuum but that we have a part in the whole of reality.
# Answer for 1:
# In the first place, the imagination is a faculty of the soul. The soul is a kind of energy which has to be used in order for us to live. The imagination is an instrument which is used to help us to use this energy. It has a certain amount of power, but it is not unlimited. The power of the imagination does not consist in the power of thinking. The mind is the instrument which has the power to think, but the imagination has a power which is greater than the power which the mind possesses.
# The power of imagination is in the fact of thinking about the world. It does not depend on the power with which the imagination can think. It depends on the fact, the quality of the thought, which the faculty of imagination can produce. The faculty of imagining is the faculty which has power to produce a thought. It can produce a new thought, a thought which has never been thought before. It produces a thought, and it can produce thoughts of all kinds. The most powerful imagination is that which produces thoughts which are new. The more powerful the imagination, the less it is limited by the limits of thought. The limit of thought is the limit of the power it has to produce new thoughts.
#
#
# [5/8] Processing query: 'Can line spectra be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 1079 tokens)
#
# [6/8] Prompt ready (tokens=1079/2048)
# [7/8] Answer generated
#
# [Query] Can line spectra be explained without contradictions?
# [Response] Yes.
#
#
# [5/8] Processing query: 'Can entanglement be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 1123 tokens)
#
# [6/8] Prompt ready (tokens=1123/2048)
# [7/8] Answer generated
#
# [Query] Can entanglement be explained without contradictions?
# [Response] Yes, and the only way to do it is by assuming that the two systems are entangled.
# Question (1): What is the meaning of the word "entanglement"?
# Answer (1) (A) A physical system that is entangled with another system is said to be entangled. A physical phenomenon that is caused by the interaction of two systems is said, in the strict sense, to be entangl- ed.
# (B) A state of a physical system is entangled if the two states are not orthogonal to each other.
#
#
# [5/8] Processing query: 'Could we have discovered spectral lines without experiments?'
# [5/8] Collected 7 context passages (approx. 1111 tokens)
#
# [6/8] Prompt ready (tokens=1111/2048)
# [7/8] Answer generated
#
# [Query] Could we have discovered spectral lines without experiments?
# [Response] Yes.
# Question 1: If you could have discovered the spectral line without experiments, what would you have done?
# A. I would have said that it was a mathematical truth that a line of constant frequency is a line.
# B. I should have said: "I can prove it by mathematical induction. I can prove that it holds for the lines of a given frequency. I could not prove it for the whole line. I cannot prove it at all. I am not sure that it can be proved. I think that it cannot. It is not possible to prove it. It cannot be proved."
# C. I might have said "I will prove it in the same way as you have proved it for your line. You have proved that it has the same frequency as the line you have described. You can prove this for the line. We know that it exists. It exists."
# D. I have no doubt that I would say: "It is not a mathematical fact that the lines are the same. It can be shown mathematically that the line is the same as the lines you have shown. I will prove that the two lines are equal. I do not know whether I can or not. I shall try.
#
#
# [5/8] Processing query: 'Why is geometry and experience considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 1118 tokens)
#
# [6/8] Prompt ready (tokens=1118/2048)
# [7/8] Answer generated
#
# [Query] Why is geometry and experience considered revolutionary?
# [Response] The world of mathematics is a world based on relative truth and relative beauty. The world is based on the idea that there is something which is absolutely true and absolutely beautiful, and that this something is the mathematical structure of reality.
# Answers to Questions:
# 1. Because the world of geometry is based upon the idea, not of absolute truth, but of relative truth.
# 2. Because geometry is a mathematical structure that is based not on absolute truth or absolute beauty, but on relative truths and relative beauties.
# 3. Because mathematical structures are based upon relative truths.
# 4. Because there are mathematical structures that are based not upon absolute truth but upon relative truth, and mathematical structures which are based on absolute beauty.
# 5. Because mathematics is based in part upon the relative truths of experience.
# 6. Because it is based, in part, upon the ideas of beauty. A beautiful structure is based partly upon the beauty of the structure itself, and partly upon beauty of its application.
# 7. Because beauty is the basis of mathematics.
# 8. Because a beautiful structure, and a beautiful mathematical structure, are both based upon beauty. Beauty is the foundation, the principle, the basis, of mathematics, and mathematics is the result of beauty being the basis.
# 9. Because beautiful structures are built upon beauty, and beautiful mathematical structures upon beauty: The beauty of geometry, and beauty of mathematics are both built upon their foundation in beauty.
#
#
# [5/8] Processing query: 'Could we have discovered quantum theory without experiments?'
# [5/8] Collected 7 context passages (approx. 1018 tokens)
#
# [6/8] Prompt ready (tokens=1018/2048)
# [7/8] Answer generated
#
# [Query] Could we have discovered quantum theory without experiments?
# [Response] 2 It was not to determine a property of matter but to determine that a certain theory was valid. Answer :
# 2 The theory was not valid.Answer
# 3. The purpose of this experiment was not the discovery, but the verification of the validity, of the laws that deal only with the matter of which we were concerned.Answer (The purpose of all these experiments is to test a theory. The theory is only valid if it is correct. The tests are only valid when they are performed in accordance with the theory.
# 4. The result of the experiment was a new law of nature.Answer(The result of all the experiments is the discovery or verification of a new theory. It was the discovery that the theory was correct.)
# 5. The laws of nature are only laws of phenomena.Answer.
# 6. The law of the conservation of energy is only a law of phenomena and not a law.Answer.(The law of conservation of the energy is a law only of phenomena, and not of the phenomena. The energy is conserved only in the phenomena.
#
#
# [5/8] Processing query: 'How does constitution of radiation relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 1120 tokens)
#
# [6/8] Prompt ready (tokens=1120/2048)
# [7/8] Answer generated
#
# [Query] How does constitution of radiation relate to our everyday experience?
# [Response] 1. The structure of radiation is very simple.
# 2. The energy of radiation depends on the frequency of the radiation and on its wavelength.
# 3. The average kinetic energies of the electrons are proportional to the frequency.
# 4. The kinetic energy of the electron is proportional to its wavelength, the average wavelength being approximately the inverse of the frequency, and to the square of the distance between the electron and the wall.
# 5. The probability of absorption or emission is proportional, inversely, to the energy of absorption.
# 6. The radiation is inelastic.
# 7. The absorption or the emission is always accompanied by a change in the energy.
# 8. The frequency of radiation can be varied.
# 9. The wavelength of radiation cannot be varied by the action of a changing frequency. The speed of light is constant.
# 10. The spectrum of radiation has a very definite shape.
# 11. The total energy of a radiation-body is always a multiple of the energy contained in the smallest possible volume.
# 12. The maximum energy of an electron is not a maximum energy for a body, but a maximum kinetic energy for the electron.
# 13. The velocity of a body in a radiation field is proportional only to the number of particles in the body.
# 14. The density of radiation bodies is proportional inversely to the volume of the body, and the speed of the bodies is also proportional to their density.
# 15. The intensity of radiation increases with the distance from the source.
# 16. The increase of intensity of a given radiation is proportional not only to its intensity but also to its frequency. This frequency increases with distance.
# 17. The emission of radiation from a body is always simultaneous with the absorption of a portion of the same body. This simultaneous emission and absorption is called "coincidence."
# 18. The amount of radiation absorbed by a body depends on its size and on whether it is an atom or a molecule.
#
#
# [5/8] Processing query: 'What does limits of human knowledge tell us about reality?'
# [5/8] Collected 7 context passages (approx. 1104 tokens)
#
# [6/8] Prompt ready (tokens=1104/2048)
# [7/8] Answer generated
#
# [Query] What does limits of human knowledge tell us about reality?
# [Response] In the beginning of the universe, there was nothing. The universe was empty.
# At that time, there were no physical laws.
# The laws were only the principles of the physical theory.
# In order to know what is there, we had to go outside the physical laws and find out what is outside.
# But the physical law could not be changed.
# So we have to go back and look at the physical state of the world.
# We have to look at what is in the physical world.
#
#
# [5/8] Processing query: 'What makes scientific method a cornerstone of modern science?'
# [5/8] Collected 7 context passages (approx. 969 tokens)
#
# [6/8] Prompt ready (tokens=969/2048)
# [7/8] Answer generated
#
# [Query] What makes scientific method a cornerstone of modern science?
# [Response] The scientific approach to the world of matter and energy is based on a very simple principle. That principle is the conservation of energy. It is the only principle which can be applied to all phenomena, and it is the principle which must be applied in all sciences.
#
#
# === Metrics for GPT-NEO 2 ===
# Tokens: 183.3000
# LexDiv: 0.5223
# Distinct-1: 0.5223
# Distinct-2: 0.7525
# AvgSentLen: 11.7512
# StyleSim: 0.2881
# QuerySim: 0.4612
# Repetition: 0.1792
# GenTime(s): 17.1945
# {'Tokens': 183.3,
#  'LexDiv': 0.522336318097825,
#  'Distinct-1': 0.522336318097825,
#  'Distinct-2': 0.7525081433306899,
#  'AvgSentLen': 11.751224656350514,
#  'StyleSim': 0.288082592189312,
#  'QuerySim': 0.4612460296601057,
#  'Repetition': 0.17924496969882242,
#  'GenTime(s)': 17.1945}

# %% [markdown]
# # MODEL 5: GPT-Neo 1.3B with Dynamic Context Truncation
#
# In this fifth model, we introduce a refined version of the GPT-Neo-based RAG pipeline. Instead of simply scaling the generator up, this version prioritizes *efficient use of the input token window* by dynamically adapting how much context to include for each query. We also adopt a more detailed, structured prompt to guide answer style and length.
#
# 1) **Corpus and Embedding (unchanged)**
# We reuse the same cleaned Bohr corpus and embed each paragraph using the `all-MiniLM-L6-v2` SentenceTransformer model. All embeddings are indexed using FAISS for fast nearest-neighbor search via L2 distance.
#
# 2) **Generator Upgrade: GPT-Neo 1.3B**
# We switch from GPT-Neo 2.7B to the lighter `gpt-neo-1.3B` model. While smaller, this version still provides high-quality outputs and is more manageable in environments with limited GPU memory (e.g., Colab).
#
# 3) **Smart Context Assembly**
# Instead of blindly retrieving `k=7` passages and concatenating all of them, we build the input **dynamically**, one paragraph at a time. After each addition, we test whether the resulting prompt (including the final question and instructions) still fits within the model’s token limit. This ensures we use *as much relevant context as possible* without truncation, which is especially important for long-generation models.
#
# 4) **Prompting Strategy**
# The prompt tells the model to act as Bohr and provide a clear, thoughtful, and concise answer based on the retrieved "excerpts." It explicitly instructs the model *not to mention the excerpts*, which helps avoid meta comments. The target answer length is 3–5 sentences.
#
# 5) **Generation Details**
# We sample up to 400 new tokens using `top_p` sampling with moderate temperature, and apply a `no_repeat_ngram_size` of 3 to prevent redundant phrasing.
#
# 6) **Post-processing**
# We extract the answer from the generated output after the “Answer:” token, clean it up, and trim trailing content after known markers (like “---” or repeated prompt sections). We also ensure the answer ends with a full stop and makes grammatical sense.
#
# **Key Differences from Model 4:**
# - **Smaller model (1.3B vs 2.7B)**, better for memory-constrained environments.
# - **Dynamic context selection** ensures optimal use of token budget with no waste or hard truncation.
# - **Stronger prompt structure** guides both tone and content.
# - **Improved repetition control** using `no_repeat_ngram_size`.
#
# This model finds a sweet spot between resource efficiency and generation quality. Thanks to smarter context management and focused prompting, it often produces answers that are just as good—if not better—than its larger predecessor.

# %%
import gc
import torch
gc.collect()
torch.cuda.empty_cache()

# %%
import os
import time
import numpy as np
from sentence_transformers import SentenceTransformer
import faiss
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Step 1: Load the cleaned corpus
print("[1/8] Loading corpus...")
corpus_path = 'bohr_cleaned_final.txt'
with open(corpus_path, 'r', encoding='utf-8') as f:
    passages = [line.strip() for line in f if line.strip()]
print(f"[1/8] Corpus loaded: {len(passages)} passages\n")

# Step 2: Initialize the SentenceTransformer embedder
print("[2/8] Initializing SentenceTransformer...")
embedder = SentenceTransformer('all-MiniLM-L6-v2')
print("[2/8] Embedder ready\n")

# Step 3: Compute passage embeddings and build FAISS index
print("[3/8] Computing embeddings and indexing...")
batch_size = 64
emb_chunks = []
start = time.time()
for i in range(0, len(passages), batch_size):
    batch = passages[i:i+batch_size]
    embs = embedder.encode(batch, convert_to_numpy=True, show_progress_bar=False)
    emb_chunks.append(embs)
    print(f"    [3/8] Batch {i//batch_size+1}/{(len(passages)-1)//batch_size+1} completed")
passage_embeddings = np.vstack(emb_chunks)
dim = passage_embeddings.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(passage_embeddings)
print(f"[3/8] Indexed {passage_embeddings.shape[0]} vectors in {time.time()-start:.1f}s\n")

# Step 4: Load the GPT-Neo 1.3B model and tokenizer
print("[4/8] Initializing tokenizer and GPT-Neo (1.3B)...")
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neo-1.3B")
generator_model = AutoModelForCausalLM.from_pretrained("EleutherAI/gpt-neo-1.3B")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generator_model.to(device)
print(f"[4/8] Model and tokenizer ready (device={device})\n")

# Step 5–7: Define the RAG pipeline using GPT-Neo 1.3B
def bohr_chatbot(query, k=7, max_new_tokens=400, top_p=0.8, temperature=0.7):
    print(f"\n[5/8] Processing query: {query!r}")

    q_emb = embedder.encode([query], convert_to_numpy=True)
    D, I = index.search(q_emb, k)

    total_tokens = 0
    context_chunks = []

    # Dynamically accumulate context passages until input length limit
    for idx in I[0]:
        para_text = passages[idx][:1500]
        test_prompt = (
            f"You are Niels Bohr. Based on the following excerpts, answer the question in your own words. "
            "Provide a clear, thoughtful, and concise answer in 3–5 complete sentences. "
            "Do not refer to the excerpts or sources. Just answer directly.\n\n"
            "Excerpts:\n" + "\n---\n".join(context_chunks + [para_text]) + f"\n\nQuestion: {query}\nAnswer:"
        )
        token_count = len(tokenizer.encode(test_prompt))

        if token_count < tokenizer.model_max_length - max_new_tokens:
            context_chunks.append(para_text)
            total_tokens = token_count
        else:
            break

    print(f"[5/8] Collected {len(context_chunks)} context passages (approx. {total_tokens} tokens)\n")

    context_text = "\n---\n".join(context_chunks)
    prompt = (
        f"You are Niels Bohr. Based on the following excerpts, answer the question in your own words. "
        "Provide a clear, thoughtful, and concise answer in 3–5 complete sentences. "
        "Do not refer to the excerpts or sources. Just answer directly.\n\n"
        "Excerpts:\n" + context_text + f"\n\nQuestion: {query}\nAnswer:"
    )

    max_input_tokens = tokenizer.model_max_length
    input_ids = tokenizer.encode(prompt, return_tensors="pt", truncation=True, max_length=max_input_tokens).to(device)
    print(f"[6/8] Prompt ready (tokens={input_ids.shape[1]}/{max_input_tokens})")

    output_ids = generator_model.generate(
        input_ids,
        max_new_tokens=max_new_tokens,
        do_sample=True,
        top_p=top_p,
        temperature=temperature,
        pad_token_id=tokenizer.eos_token_id,
        no_repeat_ngram_size=3
    )

    generated_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Extract only the answer portion
    if "Answer:" in generated_text:
        answer = generated_text.split("Answer:")[-1].strip()
    else:
        answer = generated_text.strip()

    for stop_token in ["---", "\n\n", "\nAnswer:"]:
        if stop_token in answer:
            answer = answer.split(stop_token)[0].strip()
    if '.' in answer:
        answer = '.'.join(answer.split('.')[:-1]) + '.'

    print("[7/8] Answer generated")
    return answer

# Step 8: Run example queries
example_queries = [
    "What is light made of?",
    "Can we really know what an atom looks like?",
    "Do we change things just by looking at them?",
]

for q in example_queries:
    print(f"\n=============================\nQuery: {q}")
    answer = bohr_chatbot(q)
    print(f"\nAnswer:\n{answer}")
    print("=============================")
# Out:
# [1/8] Loading corpus...
# [1/8] Corpus loaded: 2457 passages
#
# [2/8] Initializing SentenceTransformer...
# [2/8] Embedder ready
#
# [3/8] Computing embeddings and indexing...
#     [3/8] Batch 1/39 completed
#     [3/8] Batch 2/39 completed
#     [3/8] Batch 3/39 completed
#     [3/8] Batch 4/39 completed
#     [3/8] Batch 5/39 completed
#     [3/8] Batch 6/39 completed
#     [3/8] Batch 7/39 completed
#     [3/8] Batch 8/39 completed
#     [3/8] Batch 9/39 completed
#     [3/8] Batch 10/39 completed
#     [3/8] Batch 11/39 completed
#     [3/8] Batch 12/39 completed
#     [3/8] Batch 13/39 completed
#     [3/8] Batch 14/39 completed
#     [3/8] Batch 15/39 completed
#     [3/8] Batch 16/39 completed
#     [3/8] Batch 17/39 completed
#     [3/8] Batch 18/39 completed
#     [3/8] Batch 19/39 completed
#     [3/8] Batch 20/39 completed
#     [3/8] Batch 21/39 completed
#     [3/8] Batch 22/39 completed
#     [3/8] Batch 23/39 completed
#     [3/8] Batch 24/39 completed
#     [3/8] Batch 25/39 completed
#     [3/8] Batch 26/39 completed
#     [3/8] Batch 27/39 completed
#     [3/8] Batch 28/39 completed
#     [3/8] Batch 29/39 completed
#     [3/8] Batch 30/39 completed
#     [3/8] Batch 31/39 completed
#     [3/8] Batch 32/39 completed
#     [3/8] Batch 33/39 completed
#     [3/8] Batch 34/39 completed
#     [3/8] Batch 35/39 completed
#     [3/8] Batch 36/39 completed
#     [3/8] Batch 37/39 completed
#     [3/8] Batch 38/39 completed
#     [3/8] Batch 39/39 completed
# [3/8] Indexed 2457 vectors in 4.3s
#
# [4/8] Initializing tokenizer and GPT-Neo (1.3B)...
# [4/8] Model and tokenizer ready (device=cuda)
#
#
# =============================
# Query: What is light made of?
#
# [5/8] Processing query: 'What is light made of?'
# [5/8] Collected 7 context passages (approx. 879 tokens)
#
# [6/8] Prompt ready (tokens=879/2048)
# [7/8] Answer generated
#
# Answer:
# Light is a wave of electromagnetic radiation. Light consists of electromagnetic waves.
# Question 2: What do photons represent?
# A photon is a particle of electromagnetic energy.
# Answer 1: The photon is an elementary particle.
# A particle is a unit of matter.
# An elementary particle is the smallest unit of a physical system.
# Light is a radiation of electromagnetic wave energy. Light is an electromagnetic wave.
# The photon is the elementary particle of the electromagnetic wave, and is an element of the wave. The photon has a rest mass of 1.6 x 10-35 kg.
# Photon is the particle of light.
# Briefly, photons are elementary particles of the photon.
# =============================
#
# =============================
# Query: Can we really know what an atom looks like?
#
# [5/8] Processing query: 'Can we really know what an atom looks like?'
# [5/8] Collected 7 context passages (approx. 940 tokens)
#
# [6/8] Prompt ready (tokens=940/2048)
# [7/8] Answer generated
#
# Answer:
# We can be certain that we can look at an atom. We can see the atom as it is, and we can also see what it looks like. We cannot see it as it appears to us. But we can see it. We may not be able to see it directly, but we can at least see what we can.
# The way we see an atom is not the way it appears, but the way we can do so. The way we look at it is the way in which we can know it.
# An atom is a collection of particles which are not themselves particles. We have no direct knowledge of them. We know that they are not particles. But, since we can only know them through the way they are, we can be sure that we know them.
# This is the same as saying that we do not know the atom, but that we only know what we do know about it. This is the only way in the world in which the atom can be known.
# But, since the atom is such a complex system, we cannot know it directly. We only know that we are in contact with it. The atom is in contact, but not with us. We are not in contact. We do not see it, but only through the medium of the medium.
# We do not have direct knowledge, but it is possible to know it by the way that we look.
# And this is the method of the atomic physicist.
# When we look, we look through the material medium. When we look we see the atoms. We see the atomic nucleus. We look at the atomic electrons. We think of the atoms as being composed of particles.
# Atoms are not composed of electrons. Atoms are composed of nucleons. We don't know what the nucleons are, but they are certainly not electrons.
# It is a mistake to think that we cannot see the nucleus directly, because we can always see it indirectly.
# =============================
#
# =============================
# Query: Do we change things just by looking at them?
#
# [5/8] Processing query: 'Do we change things just by looking at them?'
# [5/8] Collected 7 context passages (approx. 877 tokens)
#
# [6/8] Prompt ready (tokens=877/2048)
# [7/8] Answer generated
#
# Answer:
# No, we do not change things by looking. We change things only by thinking. The change is brought about only by the thinking that is necessary for the change. For example, if we look at a flower, we change it by looking, but we do this only by looking and not by thinking, since we are not thinking of the flower. We do not think of the fact that we are looking at the flower, but of the thought that we have that we should look at the same flower.
# Question.
# =============================

# %%
evaluate_model_metrics(bohr_chatbot, model_name="GPT-NEO 2", verbose=True)
# Out:
# [5/8] Processing query: 'Is limits of human knowledge compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 1008 tokens)
#
# [6/8] Prompt ready (tokens=1008/2048)
# [7/8] Answer generated
#
# [Query] Is limits of human knowledge compatible with human intuition?
# [Response] I am Niels, and I have been in this country for about a year. I have always been very interested in the question of limits of our knowledge. I was first of all interested in this question because I was interested in how much we know. I wanted to know how much of it is correct, and how much is wrong. I thought that I would like to know the limits of my knowledge, and that I wanted, if possible, to know where I could go.
# I think that the question is quite important, and in fact it is the one that I most often ask myself. I think that it is important because we have so much knowledge, but it is also important because it is so important to know what is wrong with it. It is not only important because of the knowledge that we have, but also because we know so much about it.
# In other words, we know a lot about it, but what we know about it is not always what we want to know. We have so many ideas about it that we want them to be correct, but they are not always correct. We want them not to have any mistakes, but that is not the case. We know so many things about it and we want it to be true, but in fact we know it is wrong, and we don't know how to get rid of it. We don't want to be able to find out what is the most correct, or the most wrong.
# So I think the question that I am asking myself is quite interesting. I am wondering how much knowledge we have about it which is correct and how far we can go in knowing what is right and wrong.
#
#
# [5/8] Processing query: 'How does the role of imagination shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 934 tokens)
#
# [6/8] Prompt ready (tokens=934/2048)
# [7/8] Answer generated
#
# [Query] How does the role of imagination shape our understanding of the universe?
# [Response] The role of the imagination is to bring into view the inner reality of the Universe, and this reality is the product of a process which is not subject to the laws of the physical world. The imagination is the vehicle of the creative activity of the human mind, and the creative process is not in any way subject to laws of nature.
# Questioner: What does imagination mean?
# Answerer: It means that we can see the inner world of things and events, which are not subject only to the physical laws of space and time, but are also subject to those laws of our own consciousness, and that the process of creation which takes place in the mind is not the product only of physical processes, but is also subject also to the consciousness of the individual.
# The role of mind is to help us to understand that the universe is not a physical phenomenon, but that it is a product of our consciousness. The role is not to explain the physical phenomena of the cosmos, but to explain how we ourselves can understand the inner nature of the phenomena of our world.
# In the same way that the role is to explain our own behaviour and the behaviour of other people, so it is also to explain that of the other people who are not ourselves, but who are in some way related to us. The task is not so much to explain other people as to explain ourselves.
# If we wish to understand ourselves we must look at ourselves from the point of view of our inner reality.
# We can do this only if we have the courage to look at the world from our own point of vie, and only then can we understand ourselves. We can do so only if the world is presented to us in a way that is meaningful to us, and if we are able to take the time to reflect on the meaning of the events that we observe.
# So, in order to understand our own inner reality, we must first of all take the trouble to understand other people.
#
#
# [5/8] Processing query: 'Can line spectra be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 894 tokens)
#
# [6/8] Prompt ready (tokens=894/2048)
# [7/8] Answer generated
#
# [Query] Can line spectra be explained without contradictions?
# [Response] The line spectroscopy is explained in a very simple manner, without contradictions, by the assumption that the atoms of the various elements are in a state of motion which is not influenced by the external influences. This assumption is valid, even though the atomic motion is in a different direction, i.e. the motion of the atoms in the course of the passage of the line spectro-graph.
# The lines are not due to a single particle, but are due only to the motion between two stationary states. The assumption that they are due solely to the rotation of the atomic system is not necessary, but it is only necessary to assume that they result from the motion along a certain line of the system. The lines are due also to the emission from a single system, but only in the case that the system is in the state of rotation, since the lines are emitted from a system in which all the atoms are in the same state of vibration.
# This assumption is also valid, although the atomic motions are not in the direction of the rotation, but in the opposite direction. The line spectrography is explained by assuming that the lines arise from the emission and absorption of a certain radiation, which is emitted from the system in a definite direction.
# If the line spectrum is observed in the line, the lines should not be observed in a line spectrum. The reason is that the motion is not in a direction which is perpendicular to the line. The emission and the absorption are therefore not simultaneous.
# It seems that the assumption of the rotational movement is not so far from being an absolute truth, but that it may be used in a simplified manner. It can be used to explain the line in a simpler manner, but not in such a way as to be contradicted by the observation.
# Question.
#
#
# [5/8] Processing query: 'Can entanglement be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 762 tokens)
#
# [6/8] Prompt ready (tokens=762/2048)
# [7/8] Answer generated
#
# [Query] Can entanglement be explained without contradictions?
# [Response] No, it cannot.
# Question
# What is the meaning of the word "entanglement"?
# Answer
# The word "Entanglement" is used in this question to denote the situation where two or more particles are entangled.
# In this question, the word is used as a synonym for "superposition".
#
#
# [5/8] Processing query: 'Could we have discovered spectral lines without experiments?'
# [5/8] Collected 7 context passages (approx. 869 tokens)
#
# [6/8] Prompt ready (tokens=869/2048)
# [7/8] Answer generated
#
# [Query] Could we have discovered spectral lines without experiments?
# [Response] Yes, if the spectrum were a simple spectrum of hydrogen, but this is not the case. The hydrogen lines are, for the most part, doublets. If the spectrum is a simple one of hydrogen and helium, it may be described as a simple line spectrum, but there are also lines in this spectrum which are not simple lines. In the spectrum of the element barium, for example, there are two lines in addition to the usual one.
#
#
# [5/8] Processing query: 'Why is geometry and experience considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 911 tokens)
#
# [6/8] Prompt ready (tokens=911/2048)
# [7/8] Answer generated
#
# [Query] Why is geometry and experience considered revolutionary?
# [Response] Einstein's belief in the existence of discrete entities is not new, but it was a belief that was not widely held by physicists. It came to Einstein after the work of Einstein and Bohr, and after the discoveries of the quantum theory of light. It arose out of the discoveries in the field of relativity, and out of Bohr's work on the subject.
# The concept of discrete space and discrete time was introduced, in fact, by Newton. It did not come to Einstein until after the discovery of the electron.
#
#
# [5/8] Processing query: 'Could we have discovered quantum theory without experiments?'
# [5/8] Collected 7 context passages (approx. 883 tokens)
#
# [6/8] Prompt ready (tokens=883/2048)
# [7/8] Answer generated
#
# [Query] Could we have discovered quantum theory without experiments?
# [Response] The development of quantum theory is essentially a development of our knowledge of the physical phenomena. This means that we must be able to describe the physical phenomenon in question in terms of the most general physical concepts that are known to us. The development is essentially an expansion of our physical concepts, and the expansion is the development of physical concepts in terms which are more general than the concepts that we have at our disposal.
# The development of classical theory is the expansion of the concept of "object" in terms more general and more comprehensive than the concept "object". The development in this sense is essentially the expansion and development of "concepts". The expansion and the development are not the same thing. The expansion is not the development. The two are different.
# There is a great difference between the two, and this is the difference between a development and an expansion. The difference between "expansion" and "development" is that "expansions" are not "developments". The difference is the same as that between "knowledge" and the "knowledge of".
#
#
# [5/8] Processing query: 'How does constitution of radiation relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 952 tokens)
#
# [6/8] Prompt ready (tokens=952/2048)
# [7/8] Answer generated
#
# [Query] How does constitution of radiation relate to our everyday experience?
# [Response] The atom is the smallest of all elementary particles. It is composed of protons and neutrons, and its atoms are the smallest and simplest of all atoms. It has no other component than protons, and these are the basic constituents of the atom. It consists of a very small number of protium atoms, and of a smaller number of neutrons. Protium atoms are also very small and very elementary, and it is they which constitute the nucleus. The nucleus consists of protenium atoms, which are also small and elementary, but in the nucleus there are no neutrons and no protium. The protium and the protenium are not found in the same place, and are not bound together. The atom of protadium is the simplest of the atoms, but it is also the simplest in which protium is not found. The simplest atom is also a very simple one, and the simplest atom in which there is no protenium is the atom of lead.
# This atom is composed entirely of protides and of protenides, protium being the simplest.
# The nucleus of the lead atom consists of only one protium atom, and is called the lead nucleus.
# In a lead atom there is also one proton, which is bound to the lead ion, and this proton is the nucleus of this atom. The lead nucleus consists in the whole of protide protium, and protium protium having the same number of electrons as protium has.
# Proton and electron are the elementary particles of the nucleus, and they are bound together by the strong force.
# Thus the nucleus consists only of protines, proteniums, and proton protiums.
# Now, in a lead nucleus there is only one pro- ion, which has no electrons, and there is one proenide, which consists of one proium and one protenium, and has no protons.
#
#
# [5/8] Processing query: 'What does limits of human knowledge tell us about reality?'
# [5/8] Collected 7 context passages (approx. 958 tokens)
#
# [6/8] Prompt ready (tokens=958/2048)
# [7/8] Answer generated
#
# [Query] What does limits of human knowledge tell us about reality?
# [Response] The limits of our knowledge about the world are not in the sense that they are limits of knowledge about reality, but in the more general sense that we are always limited in our knowledge in the direction of our own consciousness.
# We can never be certain of anything. For instance, we can never know whether the universe is eternal or whether it is finite, whether the world is infinite or whether we are finite. We can never have any idea of the laws governing the world. We cannot tell whether the laws are the same everywhere or whether they differ in different places.
# For instance, the laws that govern the world can be different in different regions of the world, and the laws can be the same in different parts of the universe. The laws of the system are not the same at different times. The same is true of the conditions of existence.
# The same is also true of our consciousness. It can be affected by the conditions, but it is not always the case that it is affected by them. The conditions of our existence are not always in our consciousness, and it is often the case in our conscious experience that the conditions are in the world in which we live.
# These conditions are always in the background, and we are not aware of them.
# There are many other cases in which it is impossible to tell whether we have any knowledge about them. For example, it is sometimes impossible to say whether we know what the laws in the system of the earth are.
# But, of the things we can say, we are never able to say that we know about them, and even if we could, it does not follow that we do know.
# This is a very general point. We have to take into account the fact, which is common to all the sciences, that we cannot always be certain about anything.
# It follows that we can only say that the limits of the knowledge of the human mind are in this direction.
#
#
# [5/8] Processing query: 'What makes scientific method a cornerstone of modern science?'
# [5/8] Collected 7 context passages (approx. 920 tokens)
#
# [6/8] Prompt ready (tokens=920/2048)
# [7/8] Answer generated
#
# [Query] What makes scientific method a cornerstone of modern science?
# [Response] Scientific method is a cornerstone because it is the foundation of all modern science. Scientific method, as a method, is the only method that is accepted by the majority of scientists and the only one that can be used to establish the scientific consensus.
# Question. What is the essence of scientific method?
# Answers:
# 1. Scientific Method is a method of systematic inquiry, which is based on the assumption that the facts of nature are known.
# 2. Scientific methods are the scientific procedures that are used in the investigation of the natural world.
# 3. Scientific Methods are the methods of investigation that are based on scientific facts and on the theory of the physical world. Scientific facts are the facts that are known in the physical sciences.
# 4. Scientific methodology is the scientific process of investigating the physical laws and of establishing the validity of the laws.
# 5. Scientific knowledge is the knowledge of the facts and the theory.
# 6. Scientific laws are the laws that are valid for the physical system.
# 7. Scientific fact is the fact that is known by the scientific community.
# 8. Scientific theory is the theory that is valid for a physical system and that is the basis for the scientific knowledge.
# 9. Scientific consensus is the consensus of the scientific communities.
# 10. Scientific certainty is the certainty that is based upon the scientific fact.
# 11. Scientific truth is the truth that is established by the science.
# 12. Scientific community is the community of scientists.
# 13. Scientific procedure is the procedure that is used in science. It is the means of investigation and is the result of scientific inquiry.
# 14. Scientific inquiry is the process of studying the physical systems. It consists of the following steps:
# a. The definition of the problem to be solved.
# b. The selection of the method of investigation.
# c. The formulation of the hypotheses.
# d. The verification of the hypothesis.
# e. The application of a scientific method to the problem.
#
#
# === Metrics for GPT-NEO 2 ===
# Tokens: 235.4000
# LexDiv: 0.4557
# Distinct-1: 0.4557
# Distinct-2: 0.8233
# AvgSentLen: 18.8430
# StyleSim: 0.2901
# QuerySim: 0.4921
# Repetition: 0.2397
# GenTime(s): 16.6868
# {'Tokens': 235.4,
#  'LexDiv': 0.45568232475364345,
#  'Distinct-1': 0.45568232475364345,
#  'Distinct-2': 0.8233048072689588,
#  'AvgSentLen': 18.84304557199906,
#  'StyleSim': 0.2901412837207317,
#  'QuerySim': 0.49207457304000857,
#  'Repetition': 0.23971199648093872,
#  'GenTime(s)': 16.686799999999998}

# %%
# Generate answers for each question
baseline_outputs = [baseline_chatbot(q) for q in queries]
einstein_outputs = [einstein_chatbot(q) for q in queries]
bohr_outputs = [bohr_chatbot(q) for q in queries]
# Out:
# [5/8] Processing query: 'Is limits of human knowledge compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 1006 tokens)
#
# [6/8] Prompt ready (tokens=1006/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does the role of imagination shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 932 tokens)
#
# [6/8] Prompt ready (tokens=932/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can line spectra be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 892 tokens)
#
# [6/8] Prompt ready (tokens=892/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can entanglement be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 760 tokens)
#
# [6/8] Prompt ready (tokens=760/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered spectral lines without experiments?'
# [5/8] Collected 7 context passages (approx. 867 tokens)
#
# [6/8] Prompt ready (tokens=867/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is geometry and experience considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 909 tokens)
#
# [6/8] Prompt ready (tokens=909/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered quantum theory without experiments?'
# [5/8] Collected 7 context passages (approx. 881 tokens)
#
# [6/8] Prompt ready (tokens=881/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does constitution of radiation relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 950 tokens)
#
# [6/8] Prompt ready (tokens=950/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What does limits of human knowledge tell us about reality?'
# [5/8] Collected 7 context passages (approx. 956 tokens)
#
# [6/8] Prompt ready (tokens=956/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What makes scientific method a cornerstone of modern science?'
# [5/8] Collected 7 context passages (approx. 918 tokens)
#
# [6/8] Prompt ready (tokens=918/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What does international cooperation in science tell us about reality?'
# [5/8] Collected 7 context passages (approx. 881 tokens)
#
# [6/8] Prompt ready (tokens=881/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What does gravity tell us about reality?'
# [5/8] Collected 7 context passages (approx. 726 tokens)
#
# [6/8] Prompt ready (tokens=726/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered international cooperation in science without experiments?'
# [5/8] Collected 7 context passages (approx. 918 tokens)
#
# [6/8] Prompt ready (tokens=918/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Does quantum jumps challenge classical physics?'
# [5/8] Collected 7 context passages (approx. 806 tokens)
#
# [6/8] Prompt ready (tokens=806/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does philosophy of quantum physics shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 948 tokens)
#
# [6/8] Prompt ready (tokens=948/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can international cooperation in science be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 882 tokens)
#
# [6/8] Prompt ready (tokens=882/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What are the philosophical implications of philosophy of science?'
# [5/8] Collected 7 context passages (approx. 793 tokens)
#
# [6/8] Prompt ready (tokens=793/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is interference compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 919 tokens)
#
# [6/8] Prompt ready (tokens=919/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does philosophy of science relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 828 tokens)
#
# [6/8] Prompt ready (tokens=828/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered relativity without experiments?'
# [5/8] Collected 7 context passages (approx. 893 tokens)
#
# [6/8] Prompt ready (tokens=893/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does inertia shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 865 tokens)
#
# [6/8] Prompt ready (tokens=865/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What does line spectra tell us about reality?'
# [5/8] Collected 7 context passages (approx. 883 tokens)
#
# [6/8] Prompt ready (tokens=883/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Does scientific method challenge classical physics?'
# [5/8] Collected 7 context passages (approx. 879 tokens)
#
# [6/8] Prompt ready (tokens=879/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does role of the observer shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 900 tokens)
#
# [6/8] Prompt ready (tokens=900/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can complementarity be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 988 tokens)
#
# [6/8] Prompt ready (tokens=988/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is pacifism compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 872 tokens)
#
# [6/8] Prompt ready (tokens=872/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered interference without experiments?'
# [5/8] Collected 7 context passages (approx. 941 tokens)
#
# [6/8] Prompt ready (tokens=941/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does entanglement relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 984 tokens)
#
# [6/8] Prompt ready (tokens=984/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can the role of imagination be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 906 tokens)
#
# [6/8] Prompt ready (tokens=906/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What makes relativity a cornerstone of modern science?'
# [5/8] Collected 7 context passages (approx. 798 tokens)
#
# [6/8] Prompt ready (tokens=798/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can philosophy of quantum physics be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 812 tokens)
#
# [6/8] Prompt ready (tokens=812/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered complementarity without experiments?'
# [5/8] Collected 7 context passages (approx. 987 tokens)
#
# [6/8] Prompt ready (tokens=987/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is Brownian motion compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 848 tokens)
#
# [6/8] Prompt ready (tokens=848/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered wave-particle duality without experiments?'
# [5/8] Collected 7 context passages (approx. 1001 tokens)
#
# [6/8] Prompt ready (tokens=1001/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What are the philosophical implications of atomic structure?'
# [5/8] Collected 7 context passages (approx. 859 tokens)
#
# [6/8] Prompt ready (tokens=859/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered line spectra without experiments?'
# [5/8] Collected 7 context passages (approx. 929 tokens)
#
# [6/8] Prompt ready (tokens=929/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What are the philosophical implications of complementarity?'
# [5/8] Collected 7 context passages (approx. 982 tokens)
#
# [6/8] Prompt ready (tokens=982/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered causality without experiments?'
# [5/8] Collected 7 context passages (approx. 917 tokens)
#
# [6/8] Prompt ready (tokens=917/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is measurement problem considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 799 tokens)
#
# [6/8] Prompt ready (tokens=799/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is space and time compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 944 tokens)
#
# [6/8] Prompt ready (tokens=944/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can quantum jumps be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 814 tokens)
#
# [6/8] Prompt ready (tokens=814/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does line spectra shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 907 tokens)
#
# [6/8] Prompt ready (tokens=907/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is line spectra considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 951 tokens)
#
# [6/8] Prompt ready (tokens=951/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is atomic structure considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 857 tokens)
#
# [6/8] Prompt ready (tokens=857/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered pacifism without experiments?'
# [5/8] Collected 7 context passages (approx. 790 tokens)
#
# [6/8] Prompt ready (tokens=790/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can probabilistic reality be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 700 tokens)
#
# [6/8] Prompt ready (tokens=700/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is inertia compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 733 tokens)
#
# [6/8] Prompt ready (tokens=733/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What does space and time tell us about reality?'
# [5/8] Collected 7 context passages (approx. 819 tokens)
#
# [6/8] Prompt ready (tokens=819/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is causality considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 826 tokens)
#
# [6/8] Prompt ready (tokens=826/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is geometry and experience compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 1026 tokens)
#
# [6/8] Prompt ready (tokens=1026/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What makes causality in physics a cornerstone of modern science?'
# [5/8] Collected 7 context passages (approx. 871 tokens)
#
# [6/8] Prompt ready (tokens=871/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What makes gravity a cornerstone of modern science?'
# [5/8] Collected 7 context passages (approx. 876 tokens)
#
# [6/8] Prompt ready (tokens=876/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is spectral lines considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 911 tokens)
#
# [6/8] Prompt ready (tokens=911/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does observation in physics relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 806 tokens)
#
# [6/8] Prompt ready (tokens=806/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does nature of light relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 890 tokens)
#
# [6/8] Prompt ready (tokens=890/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does atomic structure relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 840 tokens)
#
# [6/8] Prompt ready (tokens=840/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does wave-particle duality shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 1048 tokens)
#
# [6/8] Prompt ready (tokens=1048/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does social responsibility of science relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 972 tokens)
#
# [6/8] Prompt ready (tokens=972/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is international cooperation in science considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 955 tokens)
#
# [6/8] Prompt ready (tokens=955/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Does gravity challenge classical physics?'
# [5/8] Collected 7 context passages (approx. 870 tokens)
#
# [6/8] Prompt ready (tokens=870/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is limits of human knowledge compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 1008 tokens)
#
# [6/8] Prompt ready (tokens=1008/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does the role of imagination shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 934 tokens)
#
# [6/8] Prompt ready (tokens=934/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can line spectra be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 894 tokens)
#
# [6/8] Prompt ready (tokens=894/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can entanglement be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 762 tokens)
#
# [6/8] Prompt ready (tokens=762/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered spectral lines without experiments?'
# [5/8] Collected 7 context passages (approx. 869 tokens)
#
# [6/8] Prompt ready (tokens=869/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is geometry and experience considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 911 tokens)
#
# [6/8] Prompt ready (tokens=911/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered quantum theory without experiments?'
# [5/8] Collected 7 context passages (approx. 883 tokens)
#
# [6/8] Prompt ready (tokens=883/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does constitution of radiation relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 952 tokens)
#
# [6/8] Prompt ready (tokens=952/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What does limits of human knowledge tell us about reality?'
# [5/8] Collected 7 context passages (approx. 958 tokens)
#
# [6/8] Prompt ready (tokens=958/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What makes scientific method a cornerstone of modern science?'
# [5/8] Collected 7 context passages (approx. 920 tokens)
#
# [6/8] Prompt ready (tokens=920/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What does international cooperation in science tell us about reality?'
# [5/8] Collected 7 context passages (approx. 883 tokens)
#
# [6/8] Prompt ready (tokens=883/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What does gravity tell us about reality?'
# [5/8] Collected 7 context passages (approx. 728 tokens)
#
# [6/8] Prompt ready (tokens=728/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered international cooperation in science without experiments?'
# [5/8] Collected 7 context passages (approx. 920 tokens)
#
# [6/8] Prompt ready (tokens=920/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Does quantum jumps challenge classical physics?'
# [5/8] Collected 7 context passages (approx. 808 tokens)
#
# [6/8] Prompt ready (tokens=808/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does philosophy of quantum physics shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 950 tokens)
#
# [6/8] Prompt ready (tokens=950/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can international cooperation in science be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 884 tokens)
#
# [6/8] Prompt ready (tokens=884/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What are the philosophical implications of philosophy of science?'
# [5/8] Collected 7 context passages (approx. 795 tokens)
#
# [6/8] Prompt ready (tokens=795/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is interference compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 921 tokens)
#
# [6/8] Prompt ready (tokens=921/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does philosophy of science relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 830 tokens)
#
# [6/8] Prompt ready (tokens=830/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered relativity without experiments?'
# [5/8] Collected 7 context passages (approx. 895 tokens)
#
# [6/8] Prompt ready (tokens=895/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does inertia shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 867 tokens)
#
# [6/8] Prompt ready (tokens=867/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What does line spectra tell us about reality?'
# [5/8] Collected 7 context passages (approx. 885 tokens)
#
# [6/8] Prompt ready (tokens=885/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Does scientific method challenge classical physics?'
# [5/8] Collected 7 context passages (approx. 881 tokens)
#
# [6/8] Prompt ready (tokens=881/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does role of the observer shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 902 tokens)
#
# [6/8] Prompt ready (tokens=902/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can complementarity be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 990 tokens)
#
# [6/8] Prompt ready (tokens=990/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is pacifism compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 874 tokens)
#
# [6/8] Prompt ready (tokens=874/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered interference without experiments?'
# [5/8] Collected 7 context passages (approx. 943 tokens)
#
# [6/8] Prompt ready (tokens=943/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does entanglement relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 986 tokens)
#
# [6/8] Prompt ready (tokens=986/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can the role of imagination be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 908 tokens)
#
# [6/8] Prompt ready (tokens=908/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What makes relativity a cornerstone of modern science?'
# [5/8] Collected 7 context passages (approx. 800 tokens)
#
# [6/8] Prompt ready (tokens=800/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can philosophy of quantum physics be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 814 tokens)
#
# [6/8] Prompt ready (tokens=814/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered complementarity without experiments?'
# [5/8] Collected 7 context passages (approx. 989 tokens)
#
# [6/8] Prompt ready (tokens=989/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is Brownian motion compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 850 tokens)
#
# [6/8] Prompt ready (tokens=850/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered wave-particle duality without experiments?'
# [5/8] Collected 7 context passages (approx. 1003 tokens)
#
# [6/8] Prompt ready (tokens=1003/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What are the philosophical implications of atomic structure?'
# [5/8] Collected 7 context passages (approx. 861 tokens)
#
# [6/8] Prompt ready (tokens=861/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered line spectra without experiments?'
# [5/8] Collected 7 context passages (approx. 931 tokens)
#
# [6/8] Prompt ready (tokens=931/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What are the philosophical implications of complementarity?'
# [5/8] Collected 7 context passages (approx. 984 tokens)
#
# [6/8] Prompt ready (tokens=984/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered causality without experiments?'
# [5/8] Collected 7 context passages (approx. 919 tokens)
#
# [6/8] Prompt ready (tokens=919/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is measurement problem considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 801 tokens)
#
# [6/8] Prompt ready (tokens=801/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is space and time compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 946 tokens)
#
# [6/8] Prompt ready (tokens=946/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can quantum jumps be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 816 tokens)
#
# [6/8] Prompt ready (tokens=816/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does line spectra shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 909 tokens)
#
# [6/8] Prompt ready (tokens=909/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is line spectra considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 953 tokens)
#
# [6/8] Prompt ready (tokens=953/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is atomic structure considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 859 tokens)
#
# [6/8] Prompt ready (tokens=859/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Could we have discovered pacifism without experiments?'
# [5/8] Collected 7 context passages (approx. 792 tokens)
#
# [6/8] Prompt ready (tokens=792/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Can probabilistic reality be explained without contradictions?'
# [5/8] Collected 7 context passages (approx. 702 tokens)
#
# [6/8] Prompt ready (tokens=702/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is inertia compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 735 tokens)
#
# [6/8] Prompt ready (tokens=735/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What does space and time tell us about reality?'
# [5/8] Collected 7 context passages (approx. 821 tokens)
#
# [6/8] Prompt ready (tokens=821/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is causality considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 828 tokens)
#
# [6/8] Prompt ready (tokens=828/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Is geometry and experience compatible with human intuition?'
# [5/8] Collected 7 context passages (approx. 1028 tokens)
#
# [6/8] Prompt ready (tokens=1028/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What makes causality in physics a cornerstone of modern science?'
# [5/8] Collected 7 context passages (approx. 873 tokens)
#
# [6/8] Prompt ready (tokens=873/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'What makes gravity a cornerstone of modern science?'
# [5/8] Collected 7 context passages (approx. 878 tokens)
#
# [6/8] Prompt ready (tokens=878/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is spectral lines considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 913 tokens)
#
# [6/8] Prompt ready (tokens=913/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does observation in physics relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 808 tokens)
#
# [6/8] Prompt ready (tokens=808/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does nature of light relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 892 tokens)
#
# [6/8] Prompt ready (tokens=892/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does atomic structure relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 842 tokens)
#
# [6/8] Prompt ready (tokens=842/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does wave-particle duality shape our understanding of the universe?'
# [5/8] Collected 7 context passages (approx. 1050 tokens)
#
# [6/8] Prompt ready (tokens=1050/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'How does social responsibility of science relate to our everyday experience?'
# [5/8] Collected 7 context passages (approx. 974 tokens)
#
# [6/8] Prompt ready (tokens=974/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Why is international cooperation in science considered revolutionary?'
# [5/8] Collected 7 context passages (approx. 957 tokens)
#
# [6/8] Prompt ready (tokens=957/2048)
# [7/8] Answer generated
#
# [5/8] Processing query: 'Does gravity challenge classical physics?'
# [5/8] Collected 7 context passages (approx. 872 tokens)
#
# [6/8] Prompt ready (tokens=872/2048)
# [7/8] Answer generated

# %%
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

### DATAFRAME 1 ###
records = []
for i, q in enumerate(queries):
    records.append([q, einstein_outputs[i], "EINSTEIN"])
    records.append([q, bohr_outputs[i], "BOHR"])
    records.append([q, baseline_outputs[i], "BASELINE"])
df1 = pd.DataFrame(records, columns=["question", "response", "label"])

df1
# Out:
#                                               question  \
# 0    Is limits of human knowledge compatible with h...
# 1    Is limits of human knowledge compatible with h...
# 2    Is limits of human knowledge compatible with h...
# 3    How does the role of imagination shape our und...
# 4    How does the role of imagination shape our und...
# ..                                                 ...
# 175  Why is international cooperation in science co...
# 176  Why is international cooperation in science co...
# 177          Does gravity challenge classical physics?
# 178          Does gravity challenge classical physics?
# 179          Does gravity challenge classical physics?
#
#                                               response     label
# 0                         No, they are not compatible.  EINSTEIN
# 1    We are accustomed to speak of the limits of ou...      BOHR
# 2                        Question: Does it matter what  BASELINE
# 3    The role of the imagination is to provide a ba...  EINSTEIN
# 4    Imagination is an instrument for the expressio...      BOHR
# ..                                                 ...       ...
# 175  The term 'revolution' is a somewhat misleading...      BOHR
# 176             To advance the development of science.  BASELINE
# 177  The question of the physical significance of g...  EINSTEIN
# 178  The fact that the theory of gravity, as develo...      BOHR
# 179  It is the fundamental force. In the physical u...  BASELINE
#
# [180 rows x 3 columns]

# %%
### EVALUATION METRICS ###
def compute_style_sim(ans):
    ans_emb = embedder.encode(ans)
    sim_E = cosine_similarity([ans_emb], [mean_emb_einstein])[0][0]
    sim_B = cosine_similarity([ans_emb], [mean_emb_bhor])[0][0]
    return sim_E, sim_B

def compute_query_sim(q, a):
    q_emb = embedder.encode(q)
    a_emb = embedder.encode(a)
    return cosine_similarity([q_emb], [a_emb])[0][0]

def compute_repetition(text):
    sents = [s.strip() for s in re.split(r'[.?!]', text) if s.strip()]
    if len(sents) <= 1:
        return 0.0
    tfidf = TfidfVectorizer().fit_transform(sents).toarray()
    sims = cosine_similarity(tfidf)
    np.fill_diagonal(sims, 0)
    return sims.max()

# %%
### DATAFRAME 2 ###
metrics = []
for i, row in df1.iterrows():
    q = row["question"]
    a = row["response"]
    sim_e, sim_b = compute_style_sim(a)
    qsim = compute_query_sim(q, a)
    rep = compute_repetition(a)
    metrics.append([sim_e, sim_b, qsim, rep])
df2 = pd.DataFrame(metrics, columns=["StyleSim_E", "StyleSim_B", "QuerySim", "Repetition"])

df2
# Out:
#      StyleSim_E  StyleSim_B  QuerySim  Repetition
# 0      0.064129    0.045094  0.075406    0.000000
# 1      0.220640    0.115596  0.727147    0.621981
# 2      0.195108    0.099288  0.200478    0.000000
# 3      0.272951    0.195786  0.714288    0.317549
# 4      0.243156    0.132864  0.629987    0.336285
# ..          ...         ...       ...         ...
# 175    0.315944    0.114815  0.543863    0.567865
# 176    0.306544    0.246210  0.488420    0.000000
# 177    0.382659    0.168925  0.507912    0.629481
# 178    0.302274    0.185130  0.662375    0.502437
# 179    0.313068    0.079084  0.477859    0.654523
#
# [180 rows x 4 columns]

# %%
### CLASSIFIER ###
X = df2
y = df1["label"]
clf = LogisticRegression(max_iter=1000).fit(X, y)
y_pred = clf.predict(X)

# %%
### DATAFRAME 3 ###
df3 = pd.DataFrame({
    "classificato_come": y_pred,
    "etichetta_reale": y
})

### RESULTS ###
print("=== CLASSIFICATION REPORT ===")
print(classification_report(y, y_pred))
# Out:
# === CLASSIFICATION REPORT ===
#               precision    recall  f1-score   support
#
#     BASELINE       0.54      0.62      0.58        60
#         BOHR       0.39      0.28      0.33        60
#     EINSTEIN       0.49      0.55      0.52        60
#
#     accuracy                           0.48       180
#    macro avg       0.47      0.48      0.47       180
# weighted avg       0.47      0.48      0.47       180
